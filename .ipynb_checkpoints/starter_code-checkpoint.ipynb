# %% [markdown]
# # Titanic EDA Lab
#
# ### Having insights into your data can be the difference between sinking or swimming on a project. Here we'll dive into some Exploratory Data Analysis techniques on the iconic Titanic data set.

# %% [markdown]
# ## Step 1: Reading the data
#
# 1. Go to [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)
# 2. If you scroll down the page a bit, you'll see a data dictionary explaining each of the columns. Take a minute to familiarize yourself with how the csv is structured.
# 3. Download the `train.csv` file into this project
# 4. Load the csv into pandas.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train.csv')

# %%
print(train.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## Step 2: Cleaning the data
# Note: `NaN`, empty, and missing are synonymous.
#
# 2a) Create a bar chart showing how many missing values are in each column

# %%
train.isna()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# 0    False   True     False
# 1    False  False     False
# 2    False   True     False
# 3    False  False     False
# 4    False   True     False
# ..     ...    ...       ...
# 886  False   True     False
# 887  False  False     False
# 888  False   True     False
# 889  False  False     False
# 890  False   True     False
#
# [891 rows x 12 columns]

# %%
values = train.isna().sum()
print(values)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# FamilyCount      0
# IsReverend       0
# Embarked_C       0
# Embarked_Q       0
# Embarked_S       0
# Female           0
# Male             0
# dtype: int64

# %%
plt.bar(x=train.columns,height=values);

# %% [markdown]
# 2b) Which column has the most `NaN` values? How many cells in that column are empty?

# %%
#Cabin has the most Nan values with a total of 687

# %% [markdown]
# 2c) Delete all rows where `Embarked` is empty

# %%
train.Embarked.dropna(axis=0,inplace=True) #axisi[o=row,1=column] Don't forget Inplace!

# %% [markdown]
# 2d) Fill all empty cabins with **¯\\_(ツ)_/¯**

# %%
train['Cabin'].replace(np.NaN,"¯\(ツ)/¯",inplace=True)
train.Cabin.head()
# Out:
# 0    ¯\(ツ)/¯
# 1        C85
# 2    ¯\(ツ)/¯
# 3       C123
# 4    ¯\(ツ)/¯
# Name: Cabin, dtype: object

# %% [markdown]
# ## Step 3: Feature extraction
# 3a)  There are two columns that pertain to how many family members are on the boat for a given person. Create a new column called `FamilyCount` which will be the sum of those two columns.

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare    Cabin Embarked
# 0      0         A/5 21171   7.2500  ¯\(ツ)/¯        S
# 1      0          PC 17599  71.2833      C85        C
# 2      0  STON/O2. 3101282   7.9250  ¯\(ツ)/¯        S
# 3      0            113803  53.1000     C123        S
# 4      0            373450   8.0500  ¯\(ツ)/¯        S

# %%
train = train.assign(FamilyCount = train['SibSp'] + train['Parch'])
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  FamilyCount
# 0        0         A/5 21171   7.2500  ¯\(ツ)/¯        S            1
# 1        0          PC 17599  71.2833      C85        C            1
# 2        0  STON/O2. 3101282   7.9250  ¯\(ツ)/¯        S            0
# 3        0            113803  53.1000     C123        S            1
# 4        0            373450   8.0500  ¯\(ツ)/¯        S            0
# ..     ...               ...      ...      ...      ...          ...
# 886      0            211536  13.0000  ¯\(ツ)/¯        S            0
# 887      0            112053  30.0000      B42        S            0
# 888      2        W./C. 6607  23.4500  ¯\(ツ)/¯        S            3
# 889      0            111369  30.0000     C148        C            0
# 890      0            370376   7.7500  ¯\(ツ)/¯        Q            0
#
# [891 rows x 13 columns]

# %% [markdown]
# 3b) Reverends have a special title in their name. Create a column called `IsReverend`: 1 if they're a preacher, 0 if they're not.

# %%
Preacher = []
for name in train_2['Name']:
    if 'Rev' in name:
        name = '1'
        Preacher.append(name)
    else:
        name = '0'
        Preacher.append(name)

train = train.assign(IsReverend = Preacher)
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  FamilyCount  \
# 0        0         A/5 21171   7.2500  ¯\(ツ)/¯        S            1
# 1        0          PC 17599  71.2833      C85        C            1
# 2        0  STON/O2. 3101282   7.9250  ¯\(ツ)/¯        S            0
# 3        0            113803  53.1000     C123        S            1
# 4        0            373450   8.0500  ¯\(ツ)/¯        S            0
# ..     ...               ...      ...      ...      ...          ...
# 886      0            211536  13.0000  ¯\(ツ)/¯        S            0
# 887      0            112053  30.0000      B42        S            0
# 888      2        W./C. 6607  23.4500  ¯\(ツ)/¯        S            3
# 889      0            111369  30.0000     C148        C            0
# 890      0            370376   7.7500  ¯\(ツ)/¯        Q            0
#
#     IsReverend
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ..         ...
# 886          1
# 887          0
# 888          0
# 889          0
# 890          0
#
# [891 rows x 14 columns]

# %% [markdown]
# 3c) In order to feed our training data into a classification algorithm, we need to convert our categories into 1's and 0's using `pd.get_dummies`
#   1. Create 3 columns: `Embarked_C`, `Embarked_Q` and `Embarked_S`. These columns will have 1's and 0's that correspond to the `C`, `Q` and `S` values in the `Embarked` column

# %%
dummies = pd.get_dummies(train['Embarked'])
dummies

train = train.assign(Embarked_C = dummies['C'], Embarked_Q = dummies['Q'], Embarked_S = dummies['S'])
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare    Cabin Embarked  FamilyCount  \
# 0        0         A/5 21171   7.2500  ¯\(ツ)/¯        S            1
# 1        0          PC 17599  71.2833      C85        C            1
# 2        0  STON/O2. 3101282   7.9250  ¯\(ツ)/¯        S            0
# 3        0            113803  53.1000     C123        S            1
# 4        0            373450   8.0500  ¯\(ツ)/¯        S            0
# ..     ...               ...      ...      ...      ...          ...
# 886      0            211536  13.0000  ¯\(ツ)/¯        S            0
# 887      0            112053  30.0000      B42        S            0
# 888      2        W./C. 6607  23.4500  ¯\(ツ)/¯        S            3
# 889      0            111369  30.0000     C148        C            0
# 890      0            370376   7.7500  ¯\(ツ)/¯        Q            0
#
#     IsReverend  Embarked_C  Embarked_Q  Embarked_S
# 0            0           0           0           1
# 1            0           1           0           0
# 2            0           0           0           1
# 3            0           0           0           1
# 4            0           0           0           1
# ..         ...         ...         ...         ...
# 886          1           0           0           1
# 887          0           0           0           1
# 888          0           0           0           1
# 889          0           1           0           0
# 890          0           0           1           0
#
# [891 rows x 17 columns]

# %% [markdown]
#   2. Do the same thing for `Sex`

# %%
gender = pd.get_dummies(train.Sex)
train = train.assign(Female = gender['female'], Male = gender['male'])
train.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare    Cabin Embarked  \
# 886    male  27.0      0      0      211536  13.00  ¯\(ツ)/¯        S
# 887  female  19.0      0      0      112053  30.00      B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45  ¯\(ツ)/¯        S
# 889    male  26.0      0      0      111369  30.00     C148        C
# 890    male  32.0      0      0      370376   7.75  ¯\(ツ)/¯        Q
#
#      FamilyCount IsReverend  Embarked_C  Embarked_Q  Embarked_S  Female  Male
# 886            0          1           0           0           1       0     1
# 887            0          0           0           0           1       1     0
# 888            3          0           0           0           1       1     0
# 889            0          0           1           0           0       0     1
# 890            0          0           0           1           0       0     1

# %% [markdown]
#   3. BONUS: Extract the title from everyone's name and create dummy columns

# %%
#Can you show the set up for this?

# %% [markdown]
# ## Step 4: Exploratory analysis
# 4a) What was the survival rate overall?

# %%
train.Survived.mean()
# Out:
# 0.3838383838383838

# %% [markdown]
# 4b) Which gender fared the worst? What was their survival rate?

# %%
Male_stats = train.Survived & train.Male
Female_stats = train.Survived & train.Female
print(Male_stats.mean(),Female_stats.mean())
#Men have a lower survival rate of 12%
# Out:
# 0.122334455667789 0.2615039281705948

# %% [markdown]
# 4c) What was the survival rate for each `Pclass`?

# %%
Pclass_stats = train.Survived & train.Pclass
Pclass_stats.mean()
# Out:
# 0.28619528619528617

# %% [markdown]
# 4d) Did any reverends survive? How many?

# %%
train[['IsReverend','Survived']].corr()
# 1 reverend survived
# Out:
#           Survived
# Survived       1.0

# %% [markdown]
# 4e) What is the survival rate for cabins marked **¯\\_(ツ)_/¯**

# %%
stats = train[['Cabin']] == "¯\(ツ)/¯"

# %% [markdown]
# 4f) What is the survival rate for people whose `Age` is empty?

# %%
ageless_stats = train[['Survived']] > 0 , (train[['Age']] == 'Nan')
ageless_stats
# Out:
# (     Survived
#  0       False
#  1        True
#  2        True
#  3        True
#  4       False
#  ..        ...
#  886     False
#  887      True
#  888     False
#  889      True
#  890     False
#
#  [891 rows x 1 columns],
#         Age
#  0    False
#  1    False
#  2    False
#  3    False
#  4    False
#  ..     ...
#  886  False
#  887  False
#  888  False
#  889  False
#  890  False
#
#  [891 rows x 1 columns])

# %% [markdown]
# 4g) What is the survival rate for each port of embarkation?

# %%
port_stats = train['Survived'] > 0 , (train['Embarked_C'],	train['Embarked_Q'], train['Embarked_S'])
port_stats
# Out:
# (0      False
#  1       True
#  2       True
#  3       True
#  4      False
#         ...
#  886    False
#  887     True
#  888    False
#  889     True
#  890    False
#  Name: Survived, Length: 891, dtype: bool,
#  (0      0
#   1      1
#   2      0
#   3      0
#   4      0
#         ..
#   886    0
#   887    0
#   888    0
#   889    1
#   890    0
#   Name: Embarked_C, Length: 891, dtype: uint8,
#   0      0
#   1      0
#   2      0
#   3      0
#   4      0
#         ..
#   886    0
#   887    0
#   888    0
#   889    0
#   890    1
#   Name: Embarked_Q, Length: 891, dtype: uint8,
#   0      1
#   1      0
#   2      1
#   3      1
#   4      1
#         ..
#   886    1
#   887    1
#   888    1
#   889    0
#   890    0
#   Name: Embarked_S, Length: 891, dtype: uint8))

# %% [markdown]
# 4h) What is the survival rate for children (under 12) in each `Pclass`?

# %%
child_stats = train['Survived'] > 0 , (train['Age'] < 12, train['Pclass'])
child_stats
# Out:
# (0      False
#  1       True
#  2       True
#  3       True
#  4      False
#         ...
#  886    False
#  887     True
#  888    False
#  889     True
#  890    False
#  Name: Survived, Length: 891, dtype: bool,
#  (0      False
#   1      False
#   2      False
#   3      False
#   4      False
#          ...
#   886    False
#   887    False
#   888    False
#   889    False
#   890    False
#   Name: Age, Length: 891, dtype: bool,
#   0      3
#   1      1
#   2      3
#   3      1
#   4      3
#         ..
#   886    2
#   887    1
#   888    3
#   889    1
#   890    3
#   Name: Pclass, Length: 891, dtype: int64))

# %% [markdown]
# 4i) Did the captain of the ship survive? Is he on the list?

# %%
Captain_stats = train['Survived'] > 0 , (train['Name'] == ' Capt')
Captain_stats
# Out:
# (0      False
#  1       True
#  2       True
#  3       True
#  4      False
#         ...
#  886    False
#  887     True
#  888    False
#  889     True
#  890    False
#  Name: Survived, Length: 891, dtype: bool,
#  0      False
#  1      False
#  2      False
#  3      False
#  4      False
#         ...
#  886    False
#  887    False
#  888    False
#  889    False
#  890    False
#  Name: Name, Length: 891, dtype: bool)

# %% [markdown]
# 4j) Of all the people that died, who had the most expensive ticket? How much did it cost?

# %%
Expensive_ticket =train['Survived'] < 1, train['Fare'].max()
Expensive_ticket
#$512.32
# Out:
# (0       True
#  1      False
#  2      False
#  3      False
#  4       True
#         ...
#  886     True
#  887    False
#  888     True
#  889    False
#  890     True
#  Name: Survived, Length: 891, dtype: bool,
#  512.3292)

# %% [markdown]
# 4k) Does having family on the boat help or hurt your chances of survival?

# %%
#having a family hurts your chances of survival as it had a lower correlation than Male,Female and Age categgory when copared to Survival

# %% [markdown]
# ## Step 5: Plotting
# Using Matplotlib and Seaborn, create several charts showing the survival rates of different groups of people. It's fine if a handful of charts are basic (Gender, Age, etc), but what we're really looking for is something beneath the surface.
#
# *Note: Answers may vary*

# %%
sns.pairplot(train);

# %%
sns.heatmap(train.corr(), annot=True)
# Out:
# <AxesSubplot:>
